# %% [markdown]
# # Part 1

# %% [markdown]
# * Your stakeholder only wants you to include information for movies based on the following specifications:
#
# * Exclude any movie with missing values for genre or runtime
#
# * Include only full-length movies (titleType = "movie").
#
# * Include only fictional movies (not from documentary genre)
#
# * Include only movies that were released 2000 - 2021 (include 2000 and 2021)
#
# * Include only movies that were released in the United States

# %% [markdown]
# ## Imports and Data

# %%
#imports

import pandas as pd 
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
# getting urls

basics_url = 'https://datasets.imdbws.com/title.basics.tsv.gz'
akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'
ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
#storing urls

basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
akas = pd.read_csv(akas_url, sep ='\t', low_memory = False)
ratings = pd.read_csv(ratings_url, sep = '\t', low_memory = False)

# %% [markdown]
# ## Basics Data and Cleaning

# %%
# Exploring df

basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
#Checking types

basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9253132 entries, 0 to 9253131
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 635.4+ MB

# %%
# data dictionary indicates nans replaced with /N, replacing with np.nan
basics.replace({'\\N':np.nan}, inplace = True)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
# checking missing values
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1234419
# endYear           9156588
# runtimeMinutes    6775044
# genres             427815
# dtype: int64

# %%
# almost all of endYear is missing so i;m going to drop it
basics = basics.drop(columns = 'endYear')
basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9253127  tt9916848  tvEpisode              Episode #3.17
# 9253128  tt9916850  tvEpisode              Episode #3.19
# 9253129  tt9916852  tvEpisode              Episode #3.20
# 9253130  tt9916856      short                   The Wind
# 9253131  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear runtimeMinutes  \
# 0                       Carmencita       0      1894              1
# 1           Le clown et ses chiens       0      1892              5
# 2                   Pauvre Pierrot       0      1892              4
# 3                      Un bon bock       0      1892             12
# 4                 Blacksmith Scene       0      1893              1
# ...                            ...     ...       ...            ...
# 9253127              Episode #3.17       0      2010            NaN
# 9253128              Episode #3.19       0      2010            NaN
# 9253129              Episode #3.20       0      2010            NaN
# 9253130                   The Wind       0      2015             27
# 9253131  Horrid Henry Knows It All       0      2014             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9253127         Action,Drama,Family
# 9253128         Action,Drama,Family
# 9253129         Action,Drama,Family
# 9253130                       Short
# 9253131  Adventure,Animation,Comedy
#
# [9253132 rows x 8 columns]

# %%
#Dropping na columns
basics.dropna(inplace = True) 
basics.isna().sum()
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# runtimeMinutes    0
# genres            0
# dtype: int64

# %%
#checking for duplicate rows
basics.duplicated().sum()
# Out:
# 0

# %%
# looking for movies
is_movie = basics['titleType'] == 'movie'
is_movie
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 9253082     True
# 9253088    False
# 9253123    False
# 9253130    False
# 9253131    False
# Name: titleType, Length: 2374166, dtype: bool

# %%
#Changing start year dtype from object to int 
basics['startYear'] = basics['startYear'].astype(int)
#filtering out movies earlier than 2000
basics = basics.loc[(basics['startYear'] >=2000) & (basics['startYear'] <=2022) & is_movie]
basics
# Out:
#             tconst titleType  \
# 13079    tt0013274     movie
# 34792    tt0035423     movie
# 61094    tt0062336     movie
# 66309    tt0067683     movie
# 67640    tt0069049     movie
# ...            ...       ...
# 9252897  tt9916362     movie
# 9252981  tt9916538     movie
# 9253022  tt9916622     movie
# 9253049  tt9916680     movie
# 9253082  tt9916754     movie
#
#                                               primaryTitle  \
# 13079                          Istoriya grazhdanskoy voyny
# 34792                                       Kate & Leopold
# 61094    The Tango of the Widower and Its Distorting Mi...
# 66309             Workers '71: Nothing About Us Without Us
# 67640                           The Other Side of the Wind
# ...                                                    ...
# 9252897                                              Coven
# 9252981                                Kuambil Lagi Hatiku
# 9253022        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9253049  De la ilusión al desconcierto: cine colombiano...
# 9253082                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 13079                          Istoriya grazhdanskoy voyny       0       2021
# 34792                                       Kate & Leopold       0       2001
# 61094            El Tango del Viudo y Su Espejo Deformante       0       2020
# 66309                   Robotnicy 1971 - Nic o nas bez nas       0       2006
# 67640                           The Other Side of the Wind       0       2018
# ...                                                    ...     ...        ...
# 9252897                                           Akelarre       0       2020
# 9252981                                Kuambil Lagi Hatiku       0       2019
# 9253022        Rodolpho Teóphilo - O Legado de um Pioneiro       0       2015
# 9253049  De la ilusión al desconcierto: cine colombiano...       0       2007
# 9253082                     Chico Albuquerque - Revelações       0       2013
#
#         runtimeMinutes                  genres
# 13079              133             Documentary
# 34792              118  Comedy,Fantasy,Romance
# 61094               70                   Drama
# 66309               47             Documentary
# 67640              122                   Drama
# ...                ...                     ...
# 9252897             92           Drama,History
# 9252981            123                   Drama
# 9253022             57             Documentary
# 9253049            100             Documentary
# 9253082             49             Documentary
#
# [216379 rows x 8 columns]

# %%
# get data type of column 'startYear'
dataType = basics.dtypes['startYear']
print('Data type of each column startYear in the Dataframe :')
print(dataType)
# Out:
# Data type of each column startYear in the Dataframe :
# int32

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

basics
# Out:
#             tconst titleType  \
# 34792    tt0035423     movie
# 61094    tt0062336     movie
# 67640    tt0069049     movie
# 77934    tt0079644     movie
# 86771    tt0088751     movie
# ...            ...       ...
# 9252804  tt9916170     movie
# 9252813  tt9916190     movie
# 9252852  tt9916270     movie
# 9252897  tt9916362     movie
# 9252981  tt9916538     movie
#
#                                               primaryTitle  \
# 34792                                       Kate & Leopold
# 61094    The Tango of the Widower and Its Distorting Mi...
# 67640                           The Other Side of the Wind
# 77934                                        November 1828
# 86771                                    The Naked Monster
# ...                                                    ...
# 9252804                                      The Rehearsal
# 9252813                                          Safeguard
# 9252852                           Il talento del calabrone
# 9252897                                              Coven
# 9252981                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult  startYear  \
# 34792                               Kate & Leopold       0       2001
# 61094    El Tango del Viudo y Su Espejo Deformante       0       2020
# 67640                   The Other Side of the Wind       0       2018
# 77934                                November 1828       0       2001
# 86771                            The Naked Monster       0       2005
# ...                                            ...     ...        ...
# 9252804                                   O Ensaio       0       2019
# 9252813                                  Safeguard       0       2020
# 9252852                   Il talento del calabrone       0       2020
# 9252897                                   Akelarre       0       2020
# 9252981                        Kuambil Lagi Hatiku       0       2019
#
#         runtimeMinutes                     genres
# 34792              118     Comedy,Fantasy,Romance
# 61094               70                      Drama
# 67640              122                      Drama
# 77934              140                  Drama,War
# 86771              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9252804             51                      Drama
# 9252813             95  Action,Adventure,Thriller
# 9252852             84                   Thriller
# 9252897             92              Drama,History
# 9252981            123                      Drama
#
# [143291 rows x 8 columns]

# %%
#checking info is consistent
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143291 entries, 34792 to 9252981
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          143291 non-null  object
#  1   titleType       143291 non-null  object
#  2   primaryTitle    143291 non-null  object
#  3   originalTitle   143291 non-null  object
#  4   isAdult         143291 non-null  object
#  5   startYear       143291 non-null  int32
#  6   runtimeMinutes  143291 non-null  object
#  7   genres          143291 non-null  object
# dtypes: int32(1), object(7)
# memory usage: 9.3+ MB

# %% [markdown]
# ## AKAS Data and Cleaning

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33301661 entries, 0 to 33301660
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.0+ GB

# %%
# data dictionary indicates nans replaced with /N, replacing with np.nan
akas.replace({'\\N':np.nan}, inplace = True)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
akas.isna().sum()
# Out:
# titleId                   0
# ordering                  0
# title                     5
# region              1863293
# language            6271740
# types              28005451
# attributes         33054295
# isOriginalTitle        2187
# dtype: int64

# %%
# dropping remainder of nans
akas.dropna(inplace = True)
akas.isna().sum()
# Out:
# titleId            0
# ordering           0
# title              0
# region             0
# language           0
# types              0
# attributes         0
# isOriginalTitle    0
# dtype: int64

# %%
#checking for duplicates
akas.duplicated().sum()
# Out:
# 0

# %%
# checking unique values
akas.nunique()
# Out:
# titleId            435
# ordering            38
# title              451
# region               5
# language             4
# types                3
# attributes          38
# isOriginalTitle      1
# dtype: int64

# %%
#showing only movies made in the usa
is_US_Movie = akas['region'].str.contains('US',case=False)
akas = akas[is_US_Movie]
akas
# Out:
#            titleId  ordering                    title region language  \
# 100776   tt0022542         1    Di shtime fun Yisroel     US       yi
# 112683   tt0024265         4         Geleb un gelakht     US       yi
# 116064   tt0024751         9              Avram Ovenu     US       yi
# 124665   tt0026010         3  Der yidishe Kenigen Lir     US       yi
# 138101   tt0027911         1       Libe un Laydnshaft     US       yi
# 145702   tt0028902         4      Freylekhe kabtsonim     US       yi
# 146176   tt0028957         4             Grine Felder     US       yi
# 146631   tt0029013         3         Di heylige Shvue     US       yi
# 146825   tt0029042         3      Ikh vil zayn a Mame     US       yi
# 152411   tt0029765         3         Vu iz mayn Kind?     US       yi
# 160943   tt0030904         5          Tsvaye Shvester     US       yi
# 167186   tt0031697         5             Mayn Zundele     US       yi
# 173818   tt0032552         2  Der groyser Eytse-geber     US       yi
# 174081   tt0032582         2          Ir tsveyte Mame     US       yi
# 174623   tt0032649         1        Der yidisher Nigh     US       yi
# 179006   tt0033225         3   Der vilner Shtot Khazn     US       yi
# 179007   tt0033225         4    The Vilna Town Cantor     US       yi
# 1022665  tt0129068         3           Eybike Naronim     US       yi
# 1022857  tt0129118         4    Got, Mentsh, un Tayvl     US       yi
# 1023344  tt0129247         5        Mayn Yidishe Mame     US       yi
# 1026392  tt0130043         4           Am Yisroel Kay     US       yi
# 1027479  tt0130312         2             Dray Tekhter     US       yi
#
#                types          attributes isOriginalTitle
# 100776   alternative    YIVO translation               0
# 112683   alternative  modern translation               0
# 116064   alternative    YIVO translation               0
# 124665   alternative    YIVO translation               0
# 138101   alternative  modern translation               0
# 145702   alternative    YIVO translation               0
# 146176   alternative    YIVO translation               0
# 146631   alternative    YIVO translation               0
# 146825   alternative    YIVO translation               0
# 152411   alternative    YIVO translation               0
# 160943   alternative    YIVO translation               0
# 167186   alternative  modern translation               0
# 173818   alternative    YIVO translation               0
# 174081   alternative    YIVO translation               0
# 174623   alternative    YIVO translation               0
# 179006   alternative    YIVO translation               0
# 179007   alternative    YIVO translation               0
# 1022665  alternative  modern translation               0
# 1022857  alternative    YIVO translation               0
# 1023344  alternative  modern translation               0
# 1026392  alternative    YIVO translation               0
# 1027479  alternative    YIVO translation               0

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
basics
# Out:
#             tconst titleType  \
# 34792    tt0035423     movie
# 61094    tt0062336     movie
# 67640    tt0069049     movie
# 77934    tt0079644     movie
# 86771    tt0088751     movie
# ...            ...       ...
# 9252804  tt9916170     movie
# 9252813  tt9916190     movie
# 9252852  tt9916270     movie
# 9252897  tt9916362     movie
# 9252981  tt9916538     movie
#
#                                               primaryTitle  \
# 34792                                       Kate & Leopold
# 61094    The Tango of the Widower and Its Distorting Mi...
# 67640                           The Other Side of the Wind
# 77934                                        November 1828
# 86771                                    The Naked Monster
# ...                                                    ...
# 9252804                                      The Rehearsal
# 9252813                                          Safeguard
# 9252852                           Il talento del calabrone
# 9252897                                              Coven
# 9252981                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult  startYear  \
# 34792                               Kate & Leopold       0       2001
# 61094    El Tango del Viudo y Su Espejo Deformante       0       2020
# 67640                   The Other Side of the Wind       0       2018
# 77934                                November 1828       0       2001
# 86771                            The Naked Monster       0       2005
# ...                                            ...     ...        ...
# 9252804                                   O Ensaio       0       2019
# 9252813                                  Safeguard       0       2020
# 9252852                   Il talento del calabrone       0       2020
# 9252897                                   Akelarre       0       2020
# 9252981                        Kuambil Lagi Hatiku       0       2019
#
#         runtimeMinutes                     genres
# 34792              118     Comedy,Fantasy,Romance
# 61094               70                      Drama
# 67640              122                      Drama
# 77934              140                  Drama,War
# 86771              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9252804             51                      Drama
# 9252813             95  Action,Adventure,Thriller
# 9252852             84                   Thriller
# 9252897             92              Drama,History
# 9252981            123                      Drama
#
# [143291 rows x 8 columns]

# %%
#checking data is consistent
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 100776 to 1027479
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   titleId          22 non-null     object
#  1   ordering         22 non-null     int64
#  2   title            22 non-null     object
#  3   region           22 non-null     object
#  4   language         22 non-null     object
#  5   types            22 non-null     object
#  6   attributes       22 non-null     object
#  7   isOriginalTitle  22 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 1.5+ KB

# %% [markdown]
# ## Ratings Data and Cleaning

# %%
# Getting overview of the data
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1913
# 1  tt0000002            5.8       258
# 2  tt0000003            6.5      1717
# 3  tt0000004            5.6       170
# 4  tt0000005            6.2      2533

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1261565 entries, 0 to 1261564
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1261565 non-null  object
#  1   averageRating  1261565 non-null  float64
#  2   numVotes       1261565 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.9+ MB

# %%
# data dictionary indicates nans replaced with /N, replacing with np.nan
ratings.replace({'\\N':np.nan}, inplace = True)
ratings.isna().sum()
# Out:
# tconst           0
# averageRating    0
# numVotes         0
# dtype: int64

# %%
# checking duplicates
ratings.duplicated().sum()
# Out:
# 0

# %%
# Filter the basics table down to only include the US by using the filter ratings dataframe
keepers2 =basics['tconst'].isin(ratings['tconst'])
basics
# Out:
#             tconst titleType  \
# 34792    tt0035423     movie
# 61094    tt0062336     movie
# 67640    tt0069049     movie
# 77934    tt0079644     movie
# 86771    tt0088751     movie
# ...            ...       ...
# 9252804  tt9916170     movie
# 9252813  tt9916190     movie
# 9252852  tt9916270     movie
# 9252897  tt9916362     movie
# 9252981  tt9916538     movie
#
#                                               primaryTitle  \
# 34792                                       Kate & Leopold
# 61094    The Tango of the Widower and Its Distorting Mi...
# 67640                           The Other Side of the Wind
# 77934                                        November 1828
# 86771                                    The Naked Monster
# ...                                                    ...
# 9252804                                      The Rehearsal
# 9252813                                          Safeguard
# 9252852                           Il talento del calabrone
# 9252897                                              Coven
# 9252981                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult  startYear  \
# 34792                               Kate & Leopold       0       2001
# 61094    El Tango del Viudo y Su Espejo Deformante       0       2020
# 67640                   The Other Side of the Wind       0       2018
# 77934                                November 1828       0       2001
# 86771                            The Naked Monster       0       2005
# ...                                            ...     ...        ...
# 9252804                                   O Ensaio       0       2019
# 9252813                                  Safeguard       0       2020
# 9252852                   Il talento del calabrone       0       2020
# 9252897                                   Akelarre       0       2020
# 9252981                        Kuambil Lagi Hatiku       0       2019
#
#         runtimeMinutes                     genres
# 34792              118     Comedy,Fantasy,Romance
# 61094               70                      Drama
# 67640              122                      Drama
# 77934              140                  Drama,War
# 86771              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9252804             51                      Drama
# 9252813             95  Action,Adventure,Thriller
# 9252852             84                   Thriller
# 9252897             92              Drama,History
# 9252981            123                      Drama
#
# [143291 rows x 8 columns]

# %% [markdown]
# ## Saving Data as csv

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
akas.to_csv('Data/title.akas.csv.gz',compression = 'gzip', index=False)
ratings.to_csv('Data/title.ratings.csv.gz', compression = 'gzip', index=False)
